# %%
BODY_IDENTIFIERS = [
    "nose",
    "neck",
    "rightEye",
    "leftEye",
    "rightEar",
    "leftEar",
    "rightShoulder",
    "leftShoulder",
    "rightElbow",
    "leftElbow",
    "rightWrist",
    "leftWrist"
]

HAND_IDENTIFIERS = [
    "wrist",
    "indexTip",
    "indexDIP",
    "indexPIP",
    "indexMCP",
    "middleTip",
    "middleDIP",
    "middlePIP",
    "middleMCP",
    "ringTip",
    "ringDIP",
    "ringPIP",
    "ringMCP",
    "littleTip",
    "littleDIP",
    "littlePIP",
    "littleMCP",
    "thumbTip",
    "thumbIP",
    "thumbMP",
    "thumbCMC"
]

INDEX_FEATURE_PAIRS = {
    0: "middlePIP_left_Y",
    1: "littlePIP_right_Y",
    2: "middleTip_right_Y",
    3: "thumbIP_left_X",
    4: "middleMCP_right_Y",
    5: "indexMCP_right_X",
    6: "middleTip_right_X",
    7: "middlePIP_right_Y",
    8: "rightElbow_X",
    9: "indexTip_left_Y",
    10: "thumbMP_right_Y",
    11: "neck_X",
    12: "wrist_right_Y",
    13: "middleDIP_right_Y",
    14: "ringDIP_left_Y",
    15: "indexTip_right_X",
    16: "indexPIP_right_Y",
    17: "ringMCP_right_Y",
    18: "rightShoulder_Y",
    19: "littleDIP_left_Y",
    20: "thumbCMC_right_Y",
    21: "ringTip_right_X",
    22: "thumbCMC_left_X",
    23: "rightShoulder_X",
    24: "littlePIP_left_X",
    25: "thumbIP_left_Y",
    26: "thumbTip_left_Y",
    27: "littleTip_left_X",
    28: "littleTip_right_Y",
    29: "thumbCMC_left_Y",
    30: "indexMCP_left_X",
    31: "ringDIP_left_X",
    32: "middleTip_left_X",
    33: "ringPIP_left_Y",
    34: "ringPIP_left_X",
    35: "middleTip_left_Y",
    36: "ringMCP_left_Y",
    37: "littleDIP_right_Y",
    38: "indexMCP_right_Y",
    39: "wrist_right_X",
    40: "middlePIP_left_X",
    41: "littleMCP_left_X",
    42: "leftEye_X",
    43: "thumbIP_right_Y",
    44: "thumbMP_right_X",
    45: "ringPIP_right_X",
    46: "ringTip_left_X",
    47: "thumbTip_left_X",
    48: "leftShoulder_X",
    49: "littleMCP_left_Y",
    50: "thumbTip_right_Y",
    51: "middleMCP_right_X",
    52: "leftWrist_X",
    53: "indexTip_left_X",
    54: "ringMCP_left_X",
    55: "nose_X",
    56: "nose_Y",
    57: "leftElbow_Y",
    58: "ringTip_left_Y",
    59: "indexPIP_left_X",
    60: "littleTip_left_Y",
    61: "middlePIP_right_X",
    62: "neck_Y",
    63: "leftElbow_X",
    64: "rightEar_Y",
    65: "littlePIP_left_Y",
    66: "indexDIP_left_Y",
    67: "thumbMP_left_X",
    68: "rightWrist_Y",
    69: "rightElbow_Y",
    70: "indexMCP_left_Y",
    71: "rightEye_Y",
    72: "leftEar_X",
    73: "middleMCP_left_X",
    74: "indexPIP_right_X",
    75: "thumbMP_left_Y",
    76: "rightWrist_X",
    77: "leftShoulder_Y",
    78: "leftEar_Y",
    79: "indexDIP_right_Y",
    80: "littleMCP_right_X",
    81: "indexDIP_left_X",
    82: "ringMCP_right_X",
    83: "thumbIP_right_X",
    84: "indexTip_right_Y",
    85: "wrist_left_Y",
    86: "littleTip_right_X",
    87: "littleDIP_left_X",
    88: "middleDIP_left_X",
    89: "rightEar_X",
    90: "ringDIP_right_Y",
    91: "ringTip_right_Y",
    92: "ringPIP_right_Y",
    93: "middleDIP_left_Y",
    94: "thumbTip_right_X",
    95: "leftWrist_Y",
    96: "middleMCP_left_Y",
    97: "rightEye_X",
    98: "middleDIP_right_X",
    99: "littlePIP_right_X",
    100: "indexDIP_right_X",
    101: "littleDIP_right_X",
    102: "littleMCP_right_Y",
    103: "thumbCMC_right_X",
    104: "ringDIP_right_X",
    105: "wrist_left_X",
    106: "indexPIP_left_Y",
    107: "leftEye_Y" 
}

# %%
# Extract values from the dictionary and store them in a list
values_list = list(INDEX_FEATURE_PAIRS.values())

# Print the resulting list
print(values_list)
# Out:
# ['middlePIP_left_Y', 'littlePIP_right_Y', 'middleTip_right_Y', 'thumbIP_left_X', 'middleMCP_right_Y', 'indexMCP_right_X', 'middleTip_right_X', 'middlePIP_right_Y', 'rightElbow_X', 'indexTip_left_Y', 'thumbMP_right_Y', 'neck_X', 'wrist_right_Y', 'middleDIP_right_Y', 'ringDIP_left_Y', 'indexTip_right_X', 'indexPIP_right_Y', 'ringMCP_right_Y', 'rightShoulder_Y', 'littleDIP_left_Y', 'thumbCMC_right_Y', 'ringTip_right_X', 'thumbCMC_left_X', 'rightShoulder_X', 'littlePIP_left_X', 'thumbIP_left_Y', 'thumbTip_left_Y', 'littleTip_left_X', 'littleTip_right_Y', 'thumbCMC_left_Y', 'indexMCP_left_X', 'ringDIP_left_X', 'middleTip_left_X', 'ringPIP_left_Y', 'ringPIP_left_X', 'middleTip_left_Y', 'ringMCP_left_Y', 'littleDIP_right_Y', 'indexMCP_right_Y', 'wrist_right_X', 'middlePIP_left_X', 'littleMCP_left_X', 'leftEye_X', 'thumbIP_right_Y', 'thumbMP_right_X', 'ringPIP_right_X', 'ringTip_left_X', 'thumbTip_left_X', 'leftShoulder_X', 'littleMCP_left_Y', 'thumbTip_right_Y', 'middleMCP_right_X', 'leftWr
# ...

# %%
HAND_INDEX_FEATURE_PAIRS = {}

counter = 0
for identifier in HAND_IDENTIFIERS:
    for index, feature in INDEX_FEATURE_PAIRS.items():
        feature_prefix = feature.split("_")[0]
        if identifier == feature_prefix:
            counter += 1
            HAND_INDEX_FEATURE_PAIRS[index] = feature
print(counter)
# Out:
# 84

# %%
HAND_INDEX_FEATURE_PAIRS = {12: 'wrist_right_Y',
 39: 'wrist_right_X',
 85: 'wrist_left_Y',
 105: 'wrist_left_X',
 9: 'indexTip_left_Y',
 15: 'indexTip_right_X',
 53: 'indexTip_left_X',
 84: 'indexTip_right_Y',
 66: 'indexDIP_left_Y',
 79: 'indexDIP_right_Y',
 81: 'indexDIP_left_X',
 100: 'indexDIP_right_X',
 16: 'indexPIP_right_Y',
 59: 'indexPIP_left_X',
 74: 'indexPIP_right_X',
 106: 'indexPIP_left_Y',
 5: 'indexMCP_right_X',
 30: 'indexMCP_left_X',
 38: 'indexMCP_right_Y',
 70: 'indexMCP_left_Y',
 2: 'middleTip_right_Y',
 6: 'middleTip_right_X',
 32: 'middleTip_left_X',
 35: 'middleTip_left_Y',
 13: 'middleDIP_right_Y',
 88: 'middleDIP_left_X',
 93: 'middleDIP_left_Y',
 98: 'middleDIP_right_X',
 0: 'middlePIP_left_Y',
 7: 'middlePIP_right_Y',
 40: 'middlePIP_left_X',
 61: 'middlePIP_right_X',
 4: 'middleMCP_right_Y',
 51: 'middleMCP_right_X',
 73: 'middleMCP_left_X',
 96: 'middleMCP_left_Y',
 21: 'ringTip_right_X',
 46: 'ringTip_left_X',
 58: 'ringTip_left_Y',
 91: 'ringTip_right_Y',
 14: 'ringDIP_left_Y',
 31: 'ringDIP_left_X',
 90: 'ringDIP_right_Y',
 104: 'ringDIP_right_X',
 33: 'ringPIP_left_Y',
 34: 'ringPIP_left_X',
 45: 'ringPIP_right_X',
 92: 'ringPIP_right_Y',
 17: 'ringMCP_right_Y',
 36: 'ringMCP_left_Y',
 54: 'ringMCP_left_X',
 82: 'ringMCP_right_X',
 27: 'littleTip_left_X',
 28: 'littleTip_right_Y',
 60: 'littleTip_left_Y',
 86: 'littleTip_right_X',
 19: 'littleDIP_left_Y',
 37: 'littleDIP_right_Y',
 87: 'littleDIP_left_X',
 101: 'littleDIP_right_X',
 1: 'littlePIP_right_Y',
 24: 'littlePIP_left_X',
 65: 'littlePIP_left_Y',
 99: 'littlePIP_right_X',
 41: 'littleMCP_left_X',
 49: 'littleMCP_left_Y',
 80: 'littleMCP_right_X',
 102: 'littleMCP_right_Y',
 26: 'thumbTip_left_Y',
 47: 'thumbTip_left_X',
 50: 'thumbTip_right_Y',
 94: 'thumbTip_right_X',
 3: 'thumbIP_left_X',
 25: 'thumbIP_left_Y',
 43: 'thumbIP_right_Y',
 83: 'thumbIP_right_X',
 10: 'thumbMP_right_Y',
 44: 'thumbMP_right_X',
 67: 'thumbMP_left_X',
 75: 'thumbMP_left_Y',
 20: 'thumbCMC_right_Y',
 22: 'thumbCMC_left_X',
 29: 'thumbCMC_left_Y',
 103: 'thumbCMC_right_X'}
# Out:
# {12: 'wrist_right_Y',
#  39: 'wrist_right_X',
#  85: 'wrist_left_Y',
#  105: 'wrist_left_X',
#  9: 'indexTip_left_Y',
#  15: 'indexTip_right_X',
#  53: 'indexTip_left_X',
#  84: 'indexTip_right_Y',
#  66: 'indexDIP_left_Y',
#  79: 'indexDIP_right_Y',
#  81: 'indexDIP_left_X',
#  100: 'indexDIP_right_X',
#  16: 'indexPIP_right_Y',
#  59: 'indexPIP_left_X',
#  74: 'indexPIP_right_X',
#  106: 'indexPIP_left_Y',
#  5: 'indexMCP_right_X',
#  30: 'indexMCP_left_X',
#  38: 'indexMCP_right_Y',
#  70: 'indexMCP_left_Y',
#  2: 'middleTip_right_Y',
#  6: 'middleTip_right_X',
#  32: 'middleTip_left_X',
#  35: 'middleTip_left_Y',
#  13: 'middleDIP_right_Y',
#  88: 'middleDIP_left_X',
#  93: 'middleDIP_left_Y',
#  98: 'middleDIP_right_X',
#  0: 'middlePIP_left_Y',
#  7: 'middlePIP_right_Y',
#  40: 'middlePIP_left_X',
#  61: 'middlePIP_right_X',
#  4: 'middleMCP_right_Y',
#  51: 'middleMCP_right_X',
#  73: 'middleMCP_left_X',
#  96: 'middleMCP_left_Y',
#  21: 'ringTip_right_X',
# ...

# %%
BODY_INDEX_FEATURE_PAIRS = {}
counter = 0
for identifier in BODY_IDENTIFIERS:
    for index, feature in INDEX_FEATURE_PAIRS.items():
        feature_prefix = feature.split("_")[0]
        if identifier == feature_prefix:
            counter += 1
            BODY_INDEX_FEATURE_PAIRS[index] = feature
print(counter)
# Out:
# 24

# %%
BODY_INDEX_FEATURE_PAIRS = {55: 'nose_X',
 56: 'nose_Y',
 11: 'neck_X',
 62: 'neck_Y',
 71: 'rightEye_Y',
 97: 'rightEye_X',
 42: 'leftEye_X',
 107: 'leftEye_Y',
 64: 'rightEar_Y',
 89: 'rightEar_X',
 72: 'leftEar_X',
 78: 'leftEar_Y',
 18: 'rightShoulder_Y',
 23: 'rightShoulder_X',
 48: 'leftShoulder_X',
 77: 'leftShoulder_Y',
 8: 'rightElbow_X',
 69: 'rightElbow_Y',
 57: 'leftElbow_Y',
 63: 'leftElbow_X',
 68: 'rightWrist_Y',
 76: 'rightWrist_X',
 52: 'leftWrist_X',
 95: 'leftWrist_Y'}
# Out:
# {55: 'nose_X',
#  56: 'nose_Y',
#  11: 'neck_X',
#  62: 'neck_Y',
#  71: 'rightEye_Y',
#  97: 'rightEye_X',
#  42: 'leftEye_X',
#  107: 'leftEye_Y',
#  64: 'rightEar_Y',
#  89: 'rightEar_X',
#  72: 'leftEar_X',
#  78: 'leftEar_Y',
#  18: 'rightShoulder_Y',
#  23: 'rightShoulder_X',
#  48: 'leftShoulder_X',
#  77: 'leftShoulder_Y',
#  8: 'rightElbow_X',
#  69: 'rightElbow_Y',
#  57: 'leftElbow_Y',
#  63: 'leftElbow_X',
#  68: 'rightWrist_Y',
#  76: 'rightWrist_X',
#  52: 'leftWrist_X',
#  95: 'leftWrist_Y'}

# %%
import random

# Define the ranges for random values
hand_range = (0.6, 1)
body_range = (0, 0.2)

# Initialize lists with default values
hand_values = [0.0] * 108
body_values = [0.0] * 108

# Generate random values for hand positions
for index, feature in HAND_INDEX_FEATURE_PAIRS.items():
    hand_values[index] = random.uniform(hand_range[0], hand_range[1])

# Generate random values for body positions
for index, feature in BODY_INDEX_FEATURE_PAIRS.items():
    body_values[index] = random.uniform(body_range[0], body_range[1])

result_values = [hand + body for hand, body in zip(hand_values, body_values)]

# Print the generated values for verification
print("Hand Values:", hand_values)
print("Body Values:", body_values)
# Out:
# Hand Values: [0.9701553616330858, 0.7240182806195758, 0.6684434014049393, 0.8155315120470692, 0.797430653604351, 0.8508882876835007, 0.6078025052356865, 0.7942333551036916, 0.0, 0.7571700291463166, 0.7026510247268454, 0.0, 0.8804072722041976, 0.9064226310488148, 0.7221797228196497, 0.9157088740452143, 0.8614607342037686, 0.6523017129658653, 0.0, 0.6023562905139836, 0.768424575752777, 0.8162524083867116, 0.7577405748305527, 0.0, 0.60697921073866, 0.8054098631193455, 0.7824064524134992, 0.9536217814852987, 0.8348725018999258, 0.8387739942289201, 0.9518034139228435, 0.9340932017190919, 0.6021969589936192, 0.7425379720551937, 0.7366751123820584, 0.9442283975178669, 0.9537270095870708, 0.911675834240521, 0.8706479202530231, 0.8249018959696686, 0.9479535602496598, 0.7232691148291237, 0.0, 0.9210329563099489, 0.9224572354515014, 0.9890913820242856, 0.8456168184059795, 0.7396384599742402, 0.0, 0.9918911553440724, 0.8230702686572043, 0.6380423503962632, 0.0, 0.9649284046752101, 0.642361807239
# ...

# %%
# Sum up hand_values and body_values to produce a new list

# Print the result for verification
print("Result Values:", result_values)
# Out:
# Result Values: [0.42453358254131646, 0.7339562354181322, 0.4585742762492142, 0.9363790020587769, 0.7090380620860994, 0.4696690858149152, 0.9660355895241333, 0.9433671982866871, 0.09700298670998603, 0.7288480935231954, 0.5797423768863116, 0.028784587660236123, 0.5581202884515846, 0.7812239269837726, 0.7572794853543603, 0.7899864891417345, 0.8448547449737815, 0.45567753618233053, 0.1569199356207284, 0.6924352718168902, 0.4967698645062325, 0.7981098349056232, 0.967182470791468, 0.060723937696592366, 0.822318074503793, 0.7209135718164653, 0.7078467548661713, 0.5826138802699401, 0.4266667355906262, 0.9569359596576645, 0.7338222998643303, 0.6190264802652167, 0.9572947343852101, 0.811487718021852, 0.4977489987622556, 0.9922990923600314, 0.8955317415496883, 0.8719340023996605, 0.7169859206339166, 0.45097891578756966, 0.537107904853795, 0.4680525026094003, 0.15911650648970255, 0.7358138963520586, 0.65593716269128, 0.9880978749812118, 0.4056861550061077, 0.945760245966808, 0.17156459314456624,
# ...

# %%
import torch

# Convert the list to a PyTorch tensor
result_tensor = torch.tensor(result_values)

# Reshape the tensor to the desired shape
result_tensor = result_tensor.view(1, 1, -1)

# Print the tensor for verification
print("Result Tensor:", result_tensor)
print("Tensor Shape:", result_tensor.shape)
# Out:
# Result Tensor: tensor([[[0.9702, 0.7240, 0.6684, 0.8155, 0.7974, 0.8509, 0.6078, 0.7942,
#           0.1557, 0.7572, 0.7027, 0.0330, 0.8804, 0.9064, 0.7222, 0.9157,
#           0.8615, 0.6523, 0.0263, 0.6024, 0.7684, 0.8163, 0.7577, 0.0187,
#           0.6070, 0.8054, 0.7824, 0.9536, 0.8349, 0.8388, 0.9518, 0.9341,
#           0.6022, 0.7425, 0.7367, 0.9442, 0.9537, 0.9117, 0.8706, 0.8249,
#           0.9480, 0.7233, 0.1355, 0.9210, 0.9225, 0.9891, 0.8456, 0.7396,
#           0.0365, 0.9919, 0.8231, 0.6380, 0.1539, 0.9649, 0.6424, 0.0896,
#           0.0110, 0.0143, 0.9230, 0.9801, 0.6631, 0.6908, 0.1848, 0.1909,
#           0.0509, 0.7495, 0.6682, 0.8077, 0.1153, 0.0617, 0.6819, 0.0706,
#           0.0200, 0.9390, 0.9176, 0.9913, 0.1005, 0.1334, 0.1927, 0.9588,
#           0.8230, 0.7293, 0.7520, 0.6939, 0.7048, 0.7234, 0.7485, 0.7542,
#           0.7641, 0.1233, 0.6337, 0.8571, 0.9558, 0.9084, 0.6604, 0.1187,
# ...
